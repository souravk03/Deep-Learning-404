# %% [markdown]
# ![image.png](attachment:58eb95ac-b68c-45bc-a24a-3777a2b7af9c.png)

# %% [markdown]
# ![image.png](attachment:84d342ac-1747-43c2-8ff3-75dc70c0a9bb.png)

# %% [markdown]
# ![image.png](attachment:083bfca4-45e3-4fe7-825a-cd001005f13d.png)

# %% [markdown]
# ![image.png](attachment:d5b93c0f-f6a5-45e5-a030-9110aa88ac3e.png)

# %% [markdown]
# ![image.png](attachment:eaf13192-9bf3-4f71-87f7-9380228f5494.png)

# %% [markdown]
# ![image.png](attachment:145889b9-d7e5-488b-b9b7-f6f8453eb1e4.png)
