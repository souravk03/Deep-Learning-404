# %% [markdown]
# ![image.png](attachment:2fa48072-2d20-471d-8ba2-a1e27d804bdb.png)

# %% [markdown]
# ![image.png](attachment:ef5f1df0-4770-4e1b-a606-c5582788814b.png)

# %% [markdown]
# ![image.png](attachment:efcccb0e-4981-4945-b8e4-6b61c2488e2c.png)

# %% [markdown]
# ![image.png](attachment:d4792275-5eda-4f94-a7a3-ff7afed4834b.png)

# %% [markdown]
# ![image.png](attachment:24bba88c-cc33-47fb-86d4-06f4c8a420d4.png)
